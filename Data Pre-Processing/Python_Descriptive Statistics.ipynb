# %%
import numpy as np
import pandas as pd

# %%
# Load data from your CSV file (replace '[your_file].csv' with your actual file path in your project)
df = pd.read_csv("Final Dataset Assignment 2.csv")
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2105  Female  20.976842  1.710730  131.408528                            yes
# 2106  Female  21.982942  1.748584  133.742943                            yes
# 2107  Female  22.524036  1.752206  133.689352                            yes
# 2108  Female  24.361936  1.739450  133.346641                            yes
# 2109  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# Calculate descriptive statistics
descriptive_stats = df.describe()
descriptive_stats
# Out:
#                Age       Height       Weight  \
# count  2110.000000  2110.000000  2110.000000
# mean     24.311800     1.701607    86.577331
# std       6.347366     0.093271    26.194310
# min      14.000000     1.450000    39.000000
# 25%      19.946718     1.630000    65.448643
# 50%      22.774751     1.700357    83.000000
# 75%      26.000000     1.768385   107.456672
# max      61.000000     1.980000   173.000000
#
#        Consumption of Vegetables (FCVC)  Number of Main Meals (NCP)  \
# count                       2110.000000                 2110.000000
# mean                           2.423223                    2.687678
# std                            0.583909                    0.809843
# min                            1.000000                    1.000000
# 25%                            2.000000                    3.000000
# 50%                            2.000000                    3.000000
# 75%                            3.000000                    3.000000
# ...

# %%
# Add additional statistics as I have mentioned during lectures, skewness, etc are important
descriptive_stats.loc['variance'] = df.var()
descriptive_stats.loc['skewness'] = df.skew()
descriptive_stats.loc['kurtosis'] = df.kurtosis()
descriptive_stats.loc['median'] = df.median()
# Display the descriptive statistics here in python
print(descriptive_stats)
# Out:
#                   Age       Height       Weight  \
# count     2110.000000  2110.000000  2110.000000
# mean        24.311800     1.701607    86.577331
# std          6.347366     0.093271    26.194310
# min         14.000000     1.450000    39.000000
# 25%         19.946718     1.630000    65.448643
# 50%         22.774751     1.700357    83.000000
# 75%         26.000000     1.768385   107.456672
# max         61.000000     1.980000   173.000000
# variance    40.289058     0.008699   686.141889
# skewness     1.529185    -0.012520     0.256275
# kurtosis     2.824792    -0.561329    -0.699684
# median      22.774751     1.700357    83.000000
#
#           Consumption of Vegetables (FCVC)  Number of Main Meals (NCP)  \
# count                          2110.000000                 2110.000000
# mean                              2.423223                    2.687678
# std                               0.583909                    0.809843
# ...

# %%
# !pip install openpyxl

# Save the descriptive statistics to an Excel file so you can  easily use it and format it for your individual report
descriptive_stats.to_excel('Python_assignment2_descriptive_stats.xlsx')
# Out:
# ...
#      -------------------------------------- 250.9/250.9 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# Save the descriptive statistics to an Excel file so you can  easily use it and format it for your individual report
descriptive_stats.to_excel('Python_assignment2_descriptive_stats.xlsx')
